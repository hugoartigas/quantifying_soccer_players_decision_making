# %%
import pandas as pd
import numpy as np

# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# /Users/artigashugo/miniconda3/lib/python3.8/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# ...

# %%
mat = sb.matches(competition_id=11, season_id=90)
mat.head()
# Out:
# /Users/artigashugo/miniconda3/lib/python3.8/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#    match_id  match_date      kick_off      competition     season  \
# 0   3773631  2021-02-07  21:00:00.000  Spain - La Liga  2020/2021
# 1   3773665  2021-03-06  21:00:00.000  Spain - La Liga  2020/2021
# 2   3773497  2021-04-10  21:00:00.000  Spain - La Liga  2020/2021
# 3   3773660  2020-12-13  21:00:00.000  Spain - La Liga  2020/2021
# 4   3773593  2020-09-27  21:00:00.000  Spain - La Liga  2020/2021
#
#      home_team   away_team  home_score  away_score match_status  ...  \
# 0   Real Betis   Barcelona           2           3    available  ...
# 1      Osasuna   Barcelona           0           2    available  ...
# 2  Real Madrid   Barcelona           2           1    available  ...
# ...

# %%
events = sb.events(match_id=3773593)
events = events[events['team']=='Barcelona']
events.head()
# Out:
# /Users/artigashugo/miniconda3/lib/python3.8/site-packages/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#    ball_receipt_outcome ball_recovery_recovery_failure block_deflection  \
# 0                   NaN                            NaN              NaN
# 2                   NaN                            NaN              NaN
# 4                   NaN                            NaN              NaN
# 10                  NaN                            NaN              NaN
# 11                  NaN                            NaN              NaN
#
#    carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0                 NaN                  NaN                 NaN            NaN
# 2                 NaN                  NaN                 NaN            NaN
# ...

# %%
events.columns
# Out:
# Index(['ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'carry_end_location', 'clearance_aerial_won',
#        'clearance_body_part', 'clearance_head', 'clearance_left_foot',
#        'clearance_other', 'clearance_right_foot', 'counterpress',
#        'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun', 'duel_outcome',
#        'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_penalty', 'foul_committed_type', 'foul_won_advantage',
#        'foul_won_defensive', 'foul_won_penalty', 'goalkeeper_body_part',
#        'goalkeeper_end_location', 'goalkeeper_outcome', 'goalkeeper_position',
#        'goalkeeper_technique', 'goalkeeper_type', 'id', 'index',
#        'interception_outcome', 'location', 'match_id', 'minute', 'out',
#        'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
# ...

# %%
passes = events[['match_id','player_id','player','location','pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id',
       'pass_body_part', 'pass_cross', 
       'pass_end_location', 'pass_goal_assist', 'pass_height', 'pass_length', 
       'pass_no_touch', 'pass_outcome',  'pass_recipient',
       'pass_shot_assist', 'pass_switch', 'pass_technique',
       'pass_through_ball', 'pass_type','under_pressure']]
passes = passes[~passes['player_id'].isnull()]
passes = passes[~passes['pass_angle'].isnull()]
passes
# Out:
#       match_id  player_id                                            player  \
# 10     3773593     6590.0                              Norberto Murara Neto
# 11     3773593     6826.0                                   Clément Lenglet
# 12     3773593     5213.0                             Gerard Piqué Bernabéu
# 13     3773593     6826.0                                   Clément Lenglet
# 14     3773593     5213.0                             Gerard Piqué Bernabéu
# ...        ...        ...                                               ...
# 1307   3773593     5477.0                                   Ousmane Dembélé
# 1308   3773593     6947.0                                    Miralem Pjanić
# 1309   3773593     5503.0                    Lionel Andrés Messi Cuccittini
# 1310   3773593    22390.0  Francisco António Machado Mota de Castro Trincão
# 1313   3773593     5211.0                                  Jordi Alba Ramos
#
# ...

# %%
passes.pass_type.unique()
# Out:
# array(['Goal Kick', nan, 'Recovery', 'Corner', 'Throw-in', 'Interception',
#        'Free Kick', 'Kick Off'], dtype=object)

# %%
passes.pass_outcome.unique()
# Out:
# array([nan, 'Incomplete', 'Out', 'Pass Offside', 'Injury Clearance',
#        'Unknown'], dtype=object)

# %%
passes.pass_angle.value_counts()
# Out:
# -1.570796    5
#  2.034444    3
# -2.290356    2
#  3.141593    2
# -0.876058    2
#             ..
#  2.785373    1
#  2.848226    1
#  1.322506    1
# -0.983915    1
# -2.885441    1
# Name: pass_angle, Length: 718, dtype: int64

# %%
passes.pass_shot_assist.unique()
# Out:
# array([nan, True], dtype=object)

# %%
for c in passes.columns:
    if c not in ['location','pass_end_location','pass_angle','pass_length']:
        print(c)
        print(passes[c].unique())
# Out:
# match_id
# [3773593]
# player_id
# [ 6590.  6826.  5213.  5211. 30756.  8118.  6379.  5203.  5487.  3501.
#   5503. 30486.  5477.  6947. 22390.]
# player
# ['Norberto Murara Neto' 'Clément Lenglet' 'Gerard Piqué Bernabéu'
#  'Jordi Alba Ramos' 'Anssumane Fati' 'Frenkie de Jong'
#  'Sergi Roberto Carnicer' 'Sergio Busquets i Burgos' 'Antoine Griezmann'
#  'Philippe Coutinho Correia' 'Lionel Andrés Messi Cuccittini'
#  'Pedro González López' 'Ousmane Dembélé' 'Miralem Pjanić'
#  'Francisco António Machado Mota de Castro Trincão']
# pass_aerial_won
# [nan True]
# pass_assisted_shot_id
# [nan 'ef33f583-1be1-4ee3-9955-61548501cac5'
#  'df4c1ceb-9187-4846-b0a0-c0be8c158a5c'
#  'e9423194-4e80-4fc9-8af5-03bc3c9982e1'
#  '946059b3-dbec-486f-afbc-24a6c027ebc8'
#  '195c09aa-a229-4dd9-8d0c-cf1fa483053c'
#  '0266cc11-b99a-445a-a0bf-017f89bfc816'
#  'b7c7dd21-55e1-4854-ab8a-5dd81f8bf82e'
#  'd0eedb73-6876-45e6-9ab2-51b1cba444cd'
#  '8aa544cb-0369-49e1-a405-708b8459caa1'
# ...
